# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pandas in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: scikit-learn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 4)) (3.5.3)
# Requirement already satisfied: seaborn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from -r ./requirements.txt (line 5)) (0.12.1)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 79.6 MB/s eta 0:00:00
# Collecting pmdarima
#   Downloading pmdarima-2.0.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 71.4 MB/s eta 0:00:00
# Collecting darts
#   Downloading darts-0.24.0-py3-none-any.whl (693 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 693.9/693.9 kB 30.6 MB/s eta 0:00:00
# Collecting fpdf==1.7.2
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kmeans1d
#   Downloading kmeans1d-0.3.1-cp37-cp37m-manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: pip in /root/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 11)) (23.0.1)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->-r ./requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->-r ./requirements.txt (line 3)) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn->-r ./requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->-r ./requirements.txt (line 4)) (4.37.4)
# Requirement already satisfied: typing_extensions in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from seaborn->-r ./requirements.txt (line 5)) (4.4.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 43.6 MB/s eta 0:00:00
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29
#   Downloading Cython-3.0.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 91.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /root/venv/lib/python3.7/site-packages (from pmdarima->-r ./requirements.txt (line 7)) (47.1.0)
# Requirement already satisfied: urllib3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pmdarima->-r ./requirements.txt (line 7)) (1.26.12)
# Collecting lightgbm>=3.2.0
#   Downloading lightgbm-4.1.0-py3-none-manylinux_2_28_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from darts->-r ./requirements.txt (line 8)) (2.28.1)
# Collecting holidays>=0.11.1
#   Downloading holidays-0.27.1-py3-none-any.whl (598 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.5/598.5 kB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.60.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from darts->-r ./requirements.txt (line 8)) (4.64.1)
# Collecting shap>=0.40.0
#   Downloading shap-0.42.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (545 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 545.7/545.7 kB 65.3 MB/s eta 0:00:00
# Collecting statsforecast>=1.4
#   Downloading statsforecast-1.6.0-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.9/110.9 kB 24.6 MB/s eta 0:00:00
# Collecting nfoursid>=1.0.0
#   Downloading nfoursid-1.0.1-py3-none-any.whl (16 kB)
# Collecting xarray>=0.17.0
#   Downloading xarray-0.20.2-py3-none-any.whl (845 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 845.2/845.2 kB 52.2 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.8.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from darts->-r ./requirements.txt (line 8)) (1.12.1)
# Collecting catboost>=1.0.6
#   Downloading catboost-1.2.2-cp37-cp37m-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 19.9 MB/s eta 0:00:00
# Collecting pyod>=0.9.5
#   Downloading pyod-1.1.0.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 45.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting prophet>=1.1.1
#   Downloading prophet-1.1.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 84.7 MB/s eta 0:00:00
# Collecting pytorch-lightning>=1.5.0
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 45.5 MB/s eta 0:00:00
# Collecting tensorboardX>=2.1
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 23.2 MB/s eta 0:00:00
# Collecting tbats>=1.1.0
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 13.0 MB/s eta 0:00:00
# Collecting xgboost>=1.6.0
#   Downloading xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from catboost>=1.0.6->darts->-r ./requirements.txt (line 8)) (1.16.0)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: plotly in /shared-libs/python3.7/py/lib/python3.7/site-packages (from catboost>=1.0.6->darts->-r ./requirements.txt (line 8)) (5.10.0)
# Requirement already satisfied: importlib-resources in /shared-libs/python3.7/py/lib/python3.7/site-packages (from prophet>=1.1.1->darts->-r ./requirements.txt (line 8)) (5.10.0)
# Collecting LunarCalendar>=0.0.9
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 11.4 MB/s eta 0:00:00
# Collecting cmdstanpy>=1.0.4
#   Downloading cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 18.5 MB/s eta 0:00:00
# Collecting numba>=0.51
#   Downloading numba-0.56.4-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 58.5 MB/s eta 0:00:00
# Collecting PyYAML>=5.4
#   Downloading PyYAML-6.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (670 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.1/670.1 kB 36.2 MB/s eta 0:00:00
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 59.1 MB/s eta 0:00:00
# Collecting fsspec[http]>2021.06.0
#   Downloading fsspec-2023.1.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 25.6 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.6.0.post0
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests>=2.22.0->darts->-r ./requirements.txt (line 8)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.22.0->darts->-r ./requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests>=2.22.0->darts->-r ./requirements.txt (line 8)) (3.4)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting polars
#   Downloading polars-0.18.4-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 81.8 MB/s eta 0:00:00
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 116.5 MB/s eta 0:00:00
# Collecting fugue>=0.8.1
#   Downloading fugue-0.8.6-py3-none-any.whl (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.0/275.0 kB 42.8 MB/s eta 0:00:00
# Collecting protobuf>=3.20
#   Downloading protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 53.0 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from xarray>=0.17.0->darts->-r ./requirements.txt (line 8)) (5.0.0)
# Collecting pymeeus<=1,>=0.3.13
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 127.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (987 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.0/988.0 kB 73.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->-r ./requirements.txt (line 8)) (3.1.2)
# Collecting fugue-sql-antlr>=0.1.6
#   Downloading fugue-sql-antlr-0.1.7.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 44.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyarrow>=0.15.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fugue>=0.8.1->statsforecast>=1.4->darts->-r ./requirements.txt (line 8)) (9.0.0)
# Collecting sqlglot
#   Downloading sqlglot-18.11.6-py3-none-any.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.9/315.9 kB 52.3 MB/s eta 0:00:00
# Collecting triad>=0.9.1
#   Downloading triad-0.9.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 18.2 MB/s eta 0:00:00
# Collecting qpd>=0.4.4
#   Downloading qpd-0.4.4-py3-none-any.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.2/169.2 kB 49.6 MB/s eta 0:00:00
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->xarray>=0.17.0->darts->-r ./requirements.txt (line 8)) (3.9.0)
# Collecting ephem>=3.7.5.3
#   Downloading ephem-4.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 77.7 MB/s eta 0:00:00
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 53.1 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly->catboost>=1.0.6->darts->-r ./requirements.txt (line 8)) (8.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 42.4 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.2/236.2 kB 43.4 MB/s eta 0:00:00
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning>=1.5.0->darts->-r ./requirements.txt (line 8)) (22.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 16.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting antlr4-python3-runtime<4.12,>=4.11.1
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 31.0 MB/s eta 0:00:00
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jinja2->fugue>=0.8.1->statsforecast>=1.4->darts->-r ./requirements.txt (line 8)) (2.0.0)
# Collecting appdirs~=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: fpdf, pyod, fugue-sql-antlr, pymeeus
#   Building wheel for fpdf (setup.py): started
#   Building wheel for fpdf (setup.py): finished with status 'done'
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40721 sha256=5c12a52f517220dda54dc1209e1c8afbb4474950c947442ed9d4350dc750acc3
#   Stored in directory: /root/.cache/pip/wheels/d7/ca/c8/86467e7957bbbcbdf4cf4870fc7dc95e9a16404b2e3c3a98c3
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.1.0-py3-none-any.whl size=185339 sha256=de90ca21b2dc769bd4223d22868460f274695c538824de0db55b871a50c4ef5a
#   Stored in directory: /root/.cache/pip/wheels/75/8e/9b/02f164077b5120aa0255a40a516da4c800aba49fc0f7d4900c
#   Building wheel for fugue-sql-antlr (setup.py): started
#   Building wheel for fugue-sql-antlr (setup.py): finished with status 'done'
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.7-py3-none-any.whl size=158212 sha256=1460445b1b9346250333af5b06cc8756433f50e8a222044d589906e2ad4dd06a
#   Stored in directory: /root/.cache/pip/wheels/64/52/4f/e6158e830bd97a0d970561581f10ffd7de9f1dac5ee48a95c2
#   Building wheel for pymeeus (setup.py): started
#   Building wheel for pymeeus (setup.py): finished with status 'done'
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=732002 sha256=632dbe23ca667c6040c1012edefca8ff956f09a8078f4dabef115174b8f777dd
#   Stored in directory: /root/.cache/pip/wheels/1e/5a/c0/fca16a6d08089e38ac5a71f3f8ea7a9a12b3356ff3debd8c59
# Successfully built fpdf pyod fugue-sql-antlr pymeeus
# Installing collected packages: pymeeus, fpdf, ephem, appdirs, antlr4-python3-runtime, sqlglot, slicer, PyYAML, protobuf, polars, patsy, multidict, llvmlite, kmeans1d, graphviz, fsspec, fs, frozenlist, Cython, convertdate, cloudpickle, asynctest, async-timeout, yarl, xgboost, torchmetrics, tensorboardX, pandas, numba, LunarCalendar, lightning-utilities, lightgbm, holidays, aiosignal, xarray, triad, statsmodels, shap, pyod, nfoursid, cmdstanpy, catboost, aiohttp, prophet, pmdarima, fugue-sql-antlr, adagio, tbats, qpd, pytorch-lightning, fugue, statsforecast, darts
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Not uninstalling protobuf at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# Successfully installed Cython-3.0.3 LunarCalendar-0.0.9 PyYAML-6.0.1 adagio-0.2.4 aiohttp-3.8.6 aiosignal-1.3.1 antlr4-python3-runtime-4.11.1 appdirs-1.4.4 async-timeout-4.0.3 asynctest-0.13.0 catboost-1.2.2 cloudpickle-2.2.1 cmdstanpy-1.1.0 convertdate-2.4.0 darts-0.24.0 ephem-4.1.5 fpdf-1.7.2 frozenlist-1.3.3 fs-2.4.16 fsspec-2023.1.0 fugue-0.8.6 fugue-sql-antlr-0.1.7 graphviz-0.20.1 holidays-0.27.1 kmeans1d-0.3.1 lightgbm-4.1.0 lightning-utilities-0.9.0 llvmlite-0.39.1 multidict-6.0.4 nfoursid-1.0.1 numba-0.56.4 pandas-1.3.5 patsy-0.5.3 pmdarima-2.0.3 polars-0.18.4 prophet-1.1.4 protobuf-4.24.4 pymeeus-0.5.12 pyod-1.1.0 pytorch-lightning-1.9.5 qpd-0.4.4 shap-0.42.1 slicer-0.0.7 sqlglot-18.11.6 statsforecast-1.6.0 statsmodels-0.13.5 tbats-1.1.3 tensorboardX-2.6.2.2 torchmetrics-0.11.4 triad-0.9.1 xarray-0.20.2 xgboost-1.6.2 yarl-1.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.24.4 which is incompatible.
# google-cloud-spanner 3.36.0 requires sqlparse>=0.4.4, but you have sqlparse 0.4.3 which is incompatible.
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=41af8bd7-a5ed-4334-a2fe-992dcc7ea742' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
